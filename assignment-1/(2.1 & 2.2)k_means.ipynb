# %% [markdown]
# <a href="https://colab.research.google.com/github/routb68/jan-may-2023-prml-assignment/blob/main/assignment-1/(2.1%20%26%202.2)k_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question**
#
# > *2.1 Write a piece of code to run the algorithm studied in class for the K-means problem with k = 2 . Try 5 different random initialization and plot the error function w.r.t iterations in each case. In each case, plot the clusters obtained in different colors.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
df=pd.read_csv(r"/content/cm_dataset_2.csv",header=None)
df.columns=('x','y')
array=df.to_numpy()

# %%
def initial_assignment(k):
    assign=np.zeros([1000])
    import random
    for i in range(1000):
        assign[i]=random.randrange(k)
    seta=set(assign)
    while(len(seta)!=k):
        for i in range(1000):
            assign[i]=random.randrange(k)
    return assign

# %%
def find_initial_mean(k,assign):
    mean=np.zeros([k,2])
    count=np.zeros([k])
    for i in range(1000):
        mean[int(assign[i])]= np.add(mean[int(assign[i])],array[i])
        count[int(assign[i])]+=1
    for i in range(len(mean)):
        mean[i]=np.divide(mean[i], count[i])
    return mean

# %%
def k_mean_algo(k,assign,mean):
    it=0
    final_error = -1
    itlist=[]
    errorlist=[]
    while(1):
        it+=1
        itlist.append(it)
        dist=0
        error=0
        for i in range(1000):
            dist=np.linalg.norm(array[i] - mean[int(assign[i])])
            dist*=dist
            error+=dist
        errorlist.append(error)
        error_fig=plt
        #print(error)
        if(final_error == -1):
            final_error = error
        elif(final_error > error):
            final_error = error
        else:
            break
        reassign=np.zeros(1000)
        dist_arr=[0]*k
        for i in range(1000):
            for j in range(k):
                dist_arr[j]=np.linalg.norm(array[i] - mean[j])
                dist_arr[j]*=dist_arr[j]
            minpos=dist_arr.index(min(dist_arr))
            if(assign[i]==minpos):
                reassign[i]=assign[i]
            else:
                reassign[i]=minpos
        assign=reassign
        mean=np.zeros([k,2])
        count=np.zeros([k])  
        for i in range(1000):
            mean[int(assign[i])]=mean[int(assign[i])]+array[i]
            count[int(assign[i])]+=1

        for i in range(len(mean)):
            mean[i]=np.divide(mean[i], count[i])
        

    returnlist=[]
    returnlist.append(itlist)
    returnlist.append(errorlist)
    returnlist.append(assign)
    returnlist.append(mean)
    return returnlist

# %%
def error_plot(i,itlist,errorlist):
    if(i==0):
        i="FIRST"
    if(i==1):
        i="SECOND"
    if(i==2):
        i="THIRD"
    if(i==3):
        i="FOURTH"
    if(i==4):
        i="FIFTH"
    itlist = np.array(itlist)
    errorlist=np.array(errorlist)
    plt.figure(1)
    titletemp="ERROR CONVERGENCE DIAGRAM FOR" + " " + i + " " "RANDOM INITIALIZATION "
    plt.title(titletemp)
    plt.xlabel("Iteration")
    plt.ylabel("Error")
    plt.plot(itlist,errorlist)

# %%
def plot(i,mean,assign,k):
    if(i==0):
        i="FIRST"
    if(i==1):
        i="SECOND"
    if(i==2):
        i="THIRD"
    if(i==3):
        i="FOURTH"
    if(i==4):
        i="FIFTH"
    plt.figure(2)
    titletemp="CLUSTERS FOR" + " " + i + " " "RANDOM INITIALIZATION "
    plt.title(titletemp)
    print()
    print(titletemp)
    print()
    colour=['red','green','blue','orange','yellow']
    for i in range(1000):
        plt.scatter(array[i][0], array[i][1], c = colour[int(assign[i])])
    for i in range(k):
        plt.scatter(mean[i][0], mean[i][1],c=colour[i],marker='*',s=500)
    plt.show()

# %%
def starting(i):
    k=2
    assign=initial_assignment(k)
    mean=find_initial_mean(k,assign)
    returnlist=k_mean_algo(k,assign,mean)

    itlist=returnlist[0]
    errorlist=returnlist[1]
    assign=returnlist[2]
    mean=returnlist[3]
    error_plot(i,itlist,errorlist)
    plot(i,mean,assign,k)
for i in range(5):
    starting(i)
# Out:
# CLUSTERS FOR FIRST RANDOM INITIALIZATION
# CLUSTERS FOR SECOND RANDOM INITIALIZATION
# CLUSTERS FOR THIRD RANDOM INITIALIZATION
# CLUSTERS FOR FOURTH RANDOM INITIALIZATION
# CLUSTERS FOR FIFTH RANDOM INITIALIZATION

# %% [markdown]
# **Question**
#
# > *2.2 Fix a random initialization. For K = {2, 3, 4, 5}, obtain cluster centers according to K-means algorithm using the fixed initialization. For each value of K, plot the Voronoi regions associated to each cluster center. (You can assume the minimum and maximum value in the data-set to be the range for each component of R2).*

# %%
array=df.to_numpy()

def initial_assignment(k):
    assign=np.zeros([1000])
    import random
    for i in range(1000):
        assign[i]=random.randrange(k)
    seta=set(assign)
    while(len(seta)!=k):
        for i in range(1000):
            assign[i]=random.randrange(k)
    return assign


def find_initial_mean(k,assign):
    mean=np.zeros([k,2])
    count=np.zeros([k])
    for i in range(1000):
        mean[int(assign[i])]= np.add(mean[int(assign[i])],array[i])
        count[int(assign[i])]+=1
    for i in range(len(mean)):
        mean[i]=np.divide(mean[i], count[i])
    return mean

def k_mean_algo(k,assign,mean):
    it=0
    final_error = -1
    itlist=[]
    errorlist=[]
    while(1):
        it+=1
        itlist.append(it)
        dist=0
        error=0
        for i in range(1000):
            dist=np.linalg.norm(array[i] - mean[int(assign[i])])
            dist*=dist
            error+=dist
        errorlist.append(error)
        error_fig=plt
        #print(error)
        if(final_error == -1):
            final_error = error
        elif(final_error > error):
            final_error = error
        else:
            break
        reassign=np.zeros(1000)
        dist_arr=[0]*k
        for i in range(1000):
            for j in range(k):
                dist_arr[j]=np.linalg.norm(array[i] - mean[j])
                dist_arr[j]*=dist_arr[j]
            minpos=dist_arr.index(min(dist_arr))
            if(assign[i]==minpos):
                reassign[i]=assign[i]
            else:
                reassign[i]=minpos
        assign=reassign
        mean=np.zeros([k,2])
        count=np.zeros([k])  
        for i in range(1000):
            mean[int(assign[i])]=mean[int(assign[i])]+array[i]
            count[int(assign[i])]+=1

        for i in range(len(mean)):
            mean[i]=np.divide(mean[i], count[i])
        

    returnlist=[]
    returnlist.append(itlist)
    returnlist.append(errorlist)
    returnlist.append(assign)
    returnlist.append(mean)
    return returnlist


def plot(mean,assign,k):
    cluster=k
    if(k==2):
        k="2"
    if(k==3):
        k="3"
    if(k==4):
        k="4"
    if(k==5):
        k="5"
    plt.figure(2)
    titletemp="CLUSTERS FOR RANDOM INITIALIZATION FOR NUMBER OF MEAN = " + k
    print(titletemp)
    print()
    plt.title(titletemp)
    colour=['red','green','blue','orange','yellow']
    for i in range(1000):
        plt.scatter(array[i][0], array[i][1], c = colour[int(assign[i])])
    for i in range(cluster):
        plt.scatter(mean[i][0], mean[i][1],c=colour[i],marker='*',s=350)
    plt.show()
    print()



def starting(i):
    k=i    
    assign=initial_assignment(k)
    mean=find_initial_mean(k,assign)
    returnlist=k_mean_algo(k,assign,mean)

    itlist=returnlist[0]
    errorlist=returnlist[1]
    assign=returnlist[2]
    mean=returnlist[3]
    plot(mean,assign,k)

for i in range(2,6):
    starting(i)
# Out:
# CLUSTERS FOR RANDOM INITIALIZATION FOR NUMBER OF MEAN = 2
# CLUSTERS FOR RANDOM INITIALIZATION FOR NUMBER OF MEAN = 3
# <ipython-input-34-761c6dee7695>:67: RuntimeWarning: invalid value encountered in true_divide
#   mean[i]=np.divide(mean[i], count[i])
# CLUSTERS FOR RANDOM INITIALIZATION FOR NUMBER OF MEAN = 4
# CLUSTERS FOR RANDOM INITIALIZATION FOR NUMBER OF MEAN = 5
